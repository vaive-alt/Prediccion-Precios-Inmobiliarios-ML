# %% [markdown]
# <a href="https://colab.research.google.com/github/vaive-alt/Prediccion-Precios-Inmobiliarios-ML/blob/main/Prediccion_Precios_Inmobiliarios_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Fase 2: Comprensión de los Datos

# %% [markdown]
# ### Carga de los datos

# %%
import kagglehub
from kagglehub import KaggleDatasetAdapter

df = kagglehub.load_dataset(
  KaggleDatasetAdapter.PANDAS,
  "pbenavides/house-pricing-lima-peru",
  file_path
)
